# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel("C:/Users/rajan/Downloads/Sports Data.xlsx",sheet_name='Sports data')

# %%
df.head(5)
# Out:
#   Game_number Result  Avg_team_Age Match_light_type Match_format  \
# 0      Game_1   Loss          18.0              Day          ODI
# 1      Game_2    Win          24.0              Day          T20
# 2      Game_3   Loss          24.0    Day and Night          T20
# 3      Game_4    Win          24.0              NaN          ODI
# 4      Game_5   Loss          24.0            Night          ODI
#
#    Bowlers_in_team  Wicket_keeper_in_team  All_rounder_in_team  \
# 0              3.0                      1                  3.0
# 1              3.0                      1                  4.0
# 2              3.0                      1                  2.0
# 3              2.0                      1                  2.0
# 4              1.0                      1                  3.0
#
#   First_selection  Opponent  ... Max_run_scored_1over  Max_wicket_taken_1over  \
# 0         Bowling  Srilanka  ...                 13.0                       3
# ...

# %%
df=df.drop('Game_number',axis=1)

# %%
df.head()
# Out:
#   Result  Avg_team_Age Match_light_type Match_format  Bowlers_in_team  \
# 0   Loss          18.0              Day          ODI              3.0
# 1    Win          24.0              Day          T20              3.0
# 2   Loss          24.0    Day and Night          T20              3.0
# 3    Win          24.0              NaN          ODI              2.0
# 4   Loss          24.0            Night          ODI              1.0
#
#    Wicket_keeper_in_team  All_rounder_in_team First_selection  Opponent  \
# 0                      1                  3.0         Bowling  Srilanka
# 1                      1                  4.0         Batting  Zimbabwe
# 2                      1                  2.0         Bowling  Zimbabwe
# 3                      1                  2.0         Bowling     Kenya
# 4                      1                  3.0         Bowling  Srilanka
#
#    Season  ...  Max_run_scored_1over Max_wicket_taken_1over  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Result                  2930 non-null   object
#  1   Avg_team_Age            2833 non-null   float64
#  2   Match_light_type        2878 non-null   object
#  3   Match_format            2860 non-null   object
#  4   Bowlers_in_team         2848 non-null   float64
#  5   Wicket_keeper_in_team   2930 non-null   int64
#  6   All_rounder_in_team     2890 non-null   float64
#  7   First_selection         2871 non-null   object
#  8   Opponent                2894 non-null   object
#  9   Season                  2868 non-null   object
#  10  Audience_number         2849 non-null   float64
#  11  Offshore                2866 non-null   object
#  12  Max_run_scored_1over    2902 non-null   float64
#  13  Max_wicket_taken_1over  2930 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                          count          mean           std     min      25%  \
# Avg_team_Age            2833.0     29.242852      2.264230    12.0     30.0
# Bowlers_in_team         2848.0      2.913624      1.023907     1.0      2.0
# Wicket_keeper_in_team   2930.0      1.000000      0.000000     1.0      1.0
# All_rounder_in_team     2890.0      2.722491      1.092699     1.0      2.0
# Audience_number         2849.0  46267.960688  48599.581459  7063.0  20363.0
# Max_run_scored_1over    2902.0     15.199862      3.661010    11.0     12.0
# Max_wicket_taken_1over  2930.0      2.713993      1.080623     1.0      2.0
# Extra_bowls_bowled      2901.0     11.252671      7.780829     0.0      6.0
# Min_run_given_1over     2930.0      1.952560      1.678332     0.0      0.0
# Min_run_scored_1over    2903.0      2.762659      0.705759     1.0      2.0
# Max_run_given_1over     2896.0      8.669199      5.003525     6.0      6.0
# ...

# %%
df.Result.value_counts()/df.shape[0]
# Out:
# Result
# Win     0.838567
# Loss    0.161433
# Name: count, dtype: float64

# %%
print('********************************************Null Values (in %)*************************************************')
display(round(df.isna().sum()/len(df)*100))
print('********************************************Descriptive statistics*********************************************')
display(df.describe().T)

df.dropna(inplace=True)
print('********************************************Unique Values in Cols *********************************************')
print('\n')
for col in df.columns:
    if df[col].dtypes=='O':
        print('*-*-*-*-*-*-*-*-',col,'*-*-*-*-*-*-*-*-')
        print(df[col].unique())
        print('\n')
# Out:
# ********************************************Null Values (in %)*************************************************
# Result                    0.0
# Avg_team_Age              3.0
# Match_light_type          2.0
# Match_format              2.0
# Bowlers_in_team           3.0
# Wicket_keeper_in_team     0.0
# All_rounder_in_team       1.0
# First_selection           2.0
# Opponent                  1.0
# Season                    2.0
# Audience_number           3.0
# Offshore                  2.0
# Max_run_scored_1over      1.0
# Max_wicket_taken_1over    0.0
# Extra_bowls_bowled        1.0
# Min_run_given_1over       0.0
# Min_run_scored_1over      1.0
# Max_run_given_1over       1.0
# extra_bowls_opponent      0.0
# player_highest_run        1.0
# Players_scored_zero       0.0
# player_highest_wicket     0.0
# dtype: float64
# ********************************************Descriptive statistics*********************************************
# ...

# %%
# Droping NAN values because %NAN is is less than 5%
df.dropna(inplace=True)

# %%
#Replaceing 20-20 with T20 in Match_format
df.Match_format.replace("20-20",'T20',inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\3481216169.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Match_format.replace("20-20",'T20',inplace=True)

# %%
df.First_selection.replace("Bat",'Batting',inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\2375180806.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.First_selection.replace("Bat",'Batting',inplace=True)

# %%
df.Players_scored_zero.replace("Three",'3',inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\1101628159.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Players_scored_zero.replace("Three",'3',inplace=True)

# %%
df.player_highest_wicket.replace("Three",'3',inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\1745372644.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.player_highest_wicket.replace("Three",'3',inplace=True)

# %%
df.Result.replace("Win",1,inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\2459926061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Result.replace("Win",1,inplace=True)

# %%
df.Result.replace("Loss",0,inplace=True)
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\2677162499.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Result.replace("Loss",0,inplace=True)
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\2677162499.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.Result.value_counts()
# Out:
# Result
# 1    1891
# 0     367
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2258 entries, 0 to 2929
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Result                  2258 non-null   int64
#  1   Avg_team_Age            2258 non-null   float64
#  2   Match_light_type        2258 non-null   object
#  3   Match_format            2258 non-null   object
#  4   Bowlers_in_team         2258 non-null   float64
#  5   Wicket_keeper_in_team   2258 non-null   int64
#  6   All_rounder_in_team     2258 non-null   float64
#  7   First_selection         2258 non-null   object
#  8   Opponent                2258 non-null   object
#  9   Season                  2258 non-null   object
#  10  Audience_number         2258 non-null   float64
#  11  Offshore                2258 non-null   object
#  12  Max_run_scored_1over    2258 non-null   float64
#  13  Max_wicket_taken_1over  2258 non-null   int64
# ...

# %%
df.Players_scored_zero = df.Players_scored_zero.astype(int)
df.player_highest_wicket = df.player_highest_wicket.astype(int)

# %%
obj_cols=df.select_dtypes(include=['object']).columns
obj_cols
# Out:
# Index(['Match_light_type', 'Match_format', 'First_selection', 'Opponent',
#        'Season', 'Offshore'],
#       dtype='object')

# %%
for col in obj_cols:
    
    plt.figure(figsize=(4,3))
    ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
    plt.title(col+' Wise',fontdict={'fontsize': 15, 'fontweight': 'medium'})
    plt.xlabel(col+' Count',fontdict={'fontsize': 15})
    plt.ylabel(col,fontdict={'fontsize': 15})
    plt.savefig(col+'.png')
    plt.show()
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\1743287815.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\1743287815.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\1743287815.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
int_cols=df.select_dtypes(exclude=['object']).columns
int_cols
# Out:
# Index(['Result', 'Avg_team_Age', 'Bowlers_in_team', 'Wicket_keeper_in_team',
#        'All_rounder_in_team', 'Audience_number', 'Max_run_scored_1over',
#        'Max_wicket_taken_1over', 'Extra_bowls_bowled', 'Min_run_given_1over',
#        'Min_run_scored_1over', 'Max_run_given_1over', 'extra_bowls_opponent',
#        'player_highest_run', 'Players_scored_zero', 'player_highest_wicket'],
#       dtype='object')

# %%
int_cols_1=[]

# %%
for col in int_cols:
    
    plt.figure(figsize=(15,6))
    ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
    plt.title(col+' Wise',fontdict={'fontsize': 15, 'fontweight': 'medium'})
    plt.xlabel(col+' Count',fontdict={'fontsize': 15})
    plt.ylabel(col,fontdict={'fontsize': 15})
    plt.savefig(col+'.png')
    plt.show()
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\4233175759.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\4233175759.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df[col], order = df[col].value_counts().index,palette='Blues_r')
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\4233175759.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
sns.pairplot(df)

# %%
import random
data_plot=df[[i for i in df.columns if df[i].dtype!='object']]

colss=[]
for i in range(200):
    colss.append('#%06X' % random.randint(0, 0xFFFFFF))
for i in range(0,len(data_plot.columns)):
    plt.figure(figsize=(10,2))
    c=random.choice(colss)
    ax=sns.boxplot(data_plot[data_plot.columns[i]],color=c)
    ax.set_title(data_plot.columns[i],color='blue')
    plt.savefig(data_plot.columns[i]+'box.png')
    plt.show()

# %%
heat=df.corr()
plt.figure(figsize=(18,10))
kwargs = {'alpha':.9,'linewidth':10, 'linestyle':'--', 'rasterized':False, 'edgecolor':'w',  "capstyle":'projecting',}

ax=sns.heatmap(heat,annot=True,**kwargs,cmap=sns.diverging_palette(20, 220, n=200),)
plt.savefig("Heatmap"+'.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 heat=df.corr()
#       2 plt.figure(figsize=(18,10))
#       3 kwargs = {'alpha':.9,'linewidth':10, 'linestyle':'--', 'rasterized':False, 'edgecolor':'w',  "capstyle":'projecting',}
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
columns=df[[i for i in df.columns if df[i].dtype!='object']]
for col in columns:

    sns.distplot(df[col])
    #plt.savefig(col+'dist.png')
    plt.show()
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\3729803747.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\rajan\AppData\Local\Temp\ipykernel_16980\3729803747.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# ...

# %%
for col in df.select_dtypes(include=['object']).columns:
    if col not in ["Result"]:
        sns.countplot(x=df[col],hue=df['Result'],palette='Blues_r')
        #plt.savefig(col+'hue.png')
        plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=df["Opponent"],hue=df['Result'],palette='Blues_r')
#plt.savefig("Opponent"+'hue.png')
plt.show()

# %%
def outliers(var):
    a = []
    q1 = df[var].quantile(.25)
    q2 = df[var].quantile(.5)
    q3 = df[var].quantile(.75)
    iqr = q3-q1
    ulim = float(q3+(1.5*iqr))
    llim = float(q1-(1.5*iqr))

    for i in df[var]:
        if i > ulim:
            i=ulim
        elif i < llim:
            i =llim
        else:
            i=i
        a.append(i)
    return a

for col in df.select_dtypes(exclude='object').columns:
    df[col] = outliers(col)

# %%
import random
data_plot=df[[i for i in df.columns if df[i].dtype!='object']]

colss=[]
for i in range(200):
    colss.append('#%06X' % random.randint(0, 0xFFFFFF))
for i in range(0,len(data_plot.columns)):
    plt.figure(figsize=(10,2))
    c=random.choice(colss)
    ax=sns.boxplot(data_plot[data_plot.columns[i]],color=c)
    ax.set_title(data_plot.columns[i],color='blue')
    plt.savefig(data_plot.columns[i]+'box.png')
    plt.show()
